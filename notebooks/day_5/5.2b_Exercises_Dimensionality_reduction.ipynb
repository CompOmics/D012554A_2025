# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/CompOmics/D012554A_2025/blob/main/notebooks/day_5/5.2b_Exercises_Dimensionality_reduction.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # 5.2 Exercises – Dimensionality Reduction
#
# In the lecture notebook you applied PCA and MDS to synthetic and real-world
# datasets. In these exercises you will use the Breast Cancer Wisconsin dataset.

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

np.random.seed(42)

# %% [markdown]
# ---
# ## Exercise 1 – PCA on Breast Cancer data
#
# 1. Load the Breast Cancer dataset and standardise the features.
# 2. Fit PCA with all components. Plot the cumulative explained variance ratio.
# 3. How many components are needed to explain 95 % of the variance?

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 2 – 2-D PCA scatter plot
#
# 1. Project the data onto the first two principal components.
# 2. Create a scatter plot coloured by the target class (malignant / benign).
# 3. Add axis labels that include the explained variance of each PC.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 3 – MDS visualisation
#
# 1. Compute a Euclidean distance matrix from the scaled features
#    (`scipy.spatial.distance.pdist` + `squareform`).
# 2. Run MDS with 2 components on the distance matrix.
# 3. Plot the result coloured by target class and compare it visually to the PCA
#    plot from Exercise 2.

# %%
# YOUR CODE HERE
