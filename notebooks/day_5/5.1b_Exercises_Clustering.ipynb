# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/CompOmics/D012554A_2025/blob/main/notebooks/day_5/5.1b_Exercises_Clustering.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # 5.1 Exercises – Clustering
#
# In the lecture notebook you applied K-means and hierarchical agglomerative
# clustering to synthetic and gene-expression datasets. In these exercises you
# will practice on the Wine dataset from scikit-learn.

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set_context("notebook", font_scale=1.2)
sns.set_style("whitegrid")

np.random.seed(42)

# %% [markdown]
# ---
# ## Exercise 1 – Load and explore the data
#
# 1. Load the Wine dataset with `sklearn.datasets.load_wine()`.
# 2. Create a DataFrame from the feature matrix (use `data.feature_names` as
#    column names).
# 3. Standardise all features with `StandardScaler`.
# 4. Print the shape of the scaled dataset.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 2 – K-Means and the silhouette score
#
# 1. Run K-means for $k = 2, 3, \ldots, 8$ on the scaled data.
# 2. For each $k$ compute the silhouette score.
# 3. Plot silhouette score vs $k$. Which $k$ is best?

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 3 – Compare clusters with the true labels
#
# 1. Run K-means with the best $k$ you found above.
# 2. Use PCA (2 components) to project the scaled data to 2-D.
# 3. Make two scatter plots side by side: one coloured by the K-means labels,
#    one coloured by the true wine classes.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 4 – Hierarchical clustering
#
# 1. Compute a linkage matrix from the scaled data using
#    `scipy.cluster.hierarchy.linkage` with `method='ward'`.
# 2. Plot the dendrogram.
# 3. Use `seaborn.clustermap` on the scaled DataFrame (transpose it so genes are
#    rows) to create a heatmap with dendrograms on both axes.

# %%
# YOUR CODE HERE
